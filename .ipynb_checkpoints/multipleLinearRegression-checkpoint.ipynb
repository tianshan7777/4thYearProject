# %%
from sklearn import linear_model
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
#Load data
data = pd.read_csv('alberlet_rent_houses_dis.csv')
df = pd.DataFrame(data, columns = ['ID', 'Apartment', 'House', 'Room', 'Price per month', 'Size(sqm)', 'Price per sqm', 'District I', 'District II','District III','District IV','District V','District VI','District VII','District VIII','District IX','District X','District XI','District XII','District XIII','District XIV','District XV','District XVI','District XVII','District XVIII','District XIX','District XX','District XXI','District XXII','District XXIII','Number of seperated rooms','Number of half rooms','Type of building: Castle, villa','Type of building: house','Type of the building: Part of house','Type of the building: Raw house','Type of building: Semi detached house','Deposit','Utilities','Common cost', 'Furniture: Empty', 'Furniture: Equipped', 'Furniture: Furnished', 'Furniture: Partly furnished', 'Floor', 'Balconies', 'View: Courtyard, sunny', 'View: Courtyard', 'View: Garden', 'View: Panoramic', 'View: Park', 'View: Street', 'View: Street, quiet', 'View: Street, sunny', 'View: City', 'View: Hills', 'Shortest rental period', 'Children welcomed', 'American kitchen', 'Can be an office', 'Foreigners welcomed', 'Washing machine', 'Latitude', 'Longitude', 'Postcode', 'Distace to Danube', 'Distace to City Centre','Distace to Keleti','Distace to Nyugati','Distance to Deli','Distance to Airport','Distance to Eco Zone','Distance to Crime Pot','Distance to Uni1','Distance to Uni2','Distance to Uni3','Distance to Uni4','Distance to Uni5','Distance to Uni6','Distance to Uni7','Distance to Uni8','Distance to Uni9','Distance to Uni10','Distance to Uni11','Distance to Uni12','Distance to Uni13','Distance to Uni14','Distance to Uni15','Distance to Uni16','Distance to Uni17','Distance to Uni18','Distance to Uni19','Distance to Uni20','Distance to Uni21'])

print(df)
# Out:
#     ID  Apartment  House  Room  Price per month  Size(sqm)  Price per sqm  \
# 0    0          0      1     0             1206        120      10.050000
# 1    1          0      1     0             1824        310       5.883871
# 2    2          0      1     0              448         77       5.818182
# 3    3          0      1     0              773         70      11.042857
# 4    4          0      1     0              556         80       6.950000
# 5    5          0      1     0              896        130       6.892308
# 6    6          0      1     0              155         30       5.166667
# 7    7          0      1     0              680         90       7.555556
# 8    8          0      1     0              182         50       3.640000
# 9    9          0      1     0              742        140       5.300000
# 10  10          0      1     0              464        130       3.569231
# 11  11          0      1     0               91          6      15.166667
# ...

# %%
#Check for linearity
#scatter diagrams
#Number of seperated rooms

plt.scatter(df['Number of seperated rooms'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Number of seperated rooms', fontsize = 14)
plt.xlabel('Number of seperated rooms', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Deposite

plt.scatter(df['Deposit'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Deposit', fontsize = 14)
plt.xlabel('Deposit', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Utilities

plt.scatter(df['Utilities'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Utilities', fontsize = 14)
plt.xlabel('Utilities', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Common cost

plt.scatter(df['Common cost'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Common cost', fontsize = 14)
plt.xlabel('Common cost', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distace to Danube

plt.scatter(df['Distace to Danube'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distace to Danube', fontsize = 14)
plt.xlabel('Distace to Danube', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distace to City Centre

plt.scatter(df['Distace to City Centre'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distace to City Centre', fontsize = 14)
plt.xlabel('Distace to City Centre', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distace to Keleti

plt.scatter(df['Distace to Keleti'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distace to Keleti', fontsize = 14)
plt.xlabel('Distace to Keleti', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distace to Nyugati

plt.scatter(df['Distace to Nyugati'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distace to Nyugati', fontsize = 14)
plt.xlabel('Distace to Nyugati', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#distance to Deli Station

plt.scatter(df['Distance to Deli'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Deli', fontsize = 14)
plt.xlabel('Distance to Deli', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distance to Airport

plt.scatter(df['Distance to Airport'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Airport', fontsize = 14)
plt.xlabel('Distance to Airport', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distance to Eco Zone

plt.scatter(df['Distance to Eco Zone'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Eco Zone', fontsize = 14)
plt.xlabel('Distance to Eco Zone', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distance to Crime Pot

plt.scatter(df['Distance to Crime Pot'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Crime Pot', fontsize = 14)
plt.xlabel('Distance to Crime Pot', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distance to Uni1

plt.scatter(df['Distance to Uni1'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Uni1', fontsize = 14)
plt.xlabel('Distance to Uni1', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distance to Uni2

plt.scatter(df['Distance to Uni2'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Uni2', fontsize = 14)
plt.xlabel('Distance to Uni2', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distance to Uni3

plt.scatter(df['Distance to Uni3'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Uni3', fontsize = 14)
plt.xlabel('Distance to Uni3', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distance to Uni4

plt.scatter(df['Distance to Uni4'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Uni4', fontsize = 14)
plt.xlabel('Distance to Uni4', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distance to Uni5

plt.scatter(df['Distance to Uni5'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Uni5', fontsize = 14)
plt.xlabel('Distance to Uni5', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distance to Uni2

plt.scatter(df['Distance to Uni6'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Uni6', fontsize = 14)
plt.xlabel('Distance to Uni6', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distance to Uni2

plt.scatter(df['Distance to Uni7'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Uni7', fontsize = 14)
plt.xlabel('Distance to Uni7', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distance to Uni2

plt.scatter(df['Distance to Uni8'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Uni8', fontsize = 14)
plt.xlabel('Distance to Uni8', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distance to Uni2

plt.scatter(df['Distance to Uni9'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Uni9', fontsize = 14)
plt.xlabel('Distance to Uni9', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distance to Uni2

plt.scatter(df['Distance to Uni10'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Uni10', fontsize = 14)
plt.xlabel('Distance to Uni10', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distance to Uni2

plt.scatter(df['Distance to Uni11'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Uni11', fontsize = 14)
plt.xlabel('Distance to Uni11', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distance to Uni2

plt.scatter(df['Distance to Uni12'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Uni12', fontsize = 14)
plt.xlabel('Distance to Uni12', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distance to Uni2

plt.scatter(df['Distance to Uni13'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Uni13', fontsize = 14)
plt.xlabel('Distance to Uni13', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distance to Uni2

plt.scatter(df['Distance to Uni14'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Uni14', fontsize = 14)
plt.xlabel('Distance to Uni14', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distance to Uni2

plt.scatter(df['Distance to Uni15'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Uni15', fontsize = 14)
plt.xlabel('Distance to Uni15', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distance to Uni2

plt.scatter(df['Distance to Uni16'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Uni16', fontsize = 14)
plt.xlabel('Distance to Uni16', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distance to Uni2

plt.scatter(df['Distance to Uni17'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Uni17', fontsize = 14)
plt.xlabel('Distance to Uni17', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distance to Uni2

plt.scatter(df['Distance to Uni18'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Uni18', fontsize = 14)
plt.xlabel('Distance to Uni18', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distance to Uni2

plt.scatter(df['Distance to Uni19'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Uni19', fontsize = 14)
plt.xlabel('Distance to Uni19', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distance to Uni2

plt.scatter(df['Distance to Uni20'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Uni20', fontsize = 14)
plt.xlabel('Distance to Uni20', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#Check for linearity
#scatter diagrams
#Distance to Uni2

plt.scatter(df['Distance to Uni21'], df['Price per sqm'], color = 'green')
plt.title('Price per sqm VS Distance to Uni21', fontsize = 14)
plt.xlabel('Distance to Uni21', fontsize = 14)
plt.ylabel('Price per sqm', fontsize = 14)
plt.grid(True)
plt.show()

# %%
X = df[['Deposit','Utilities','Common cost','Distace to Danube', 'Distace to City Centre','Distace to Keleti','Distace to Nyugati','Distance to Deli','Distance to Airport','Distance to Eco Zone','Distance to Crime Pot','Distance to Uni1','Distance to Uni2','Distance to Uni3','Distance to Uni4','Distance to Uni5','Distance to Uni6','Distance to Uni7','Distance to Uni8','Distance to Uni9','Distance to Uni10','Distance to Uni11','Distance to Uni12','Distance to Uni13','Distance to Uni14','Distance to Uni15','Distance to Uni16','Distance to Uni17','Distance to Uni18','Distance to Uni19','Distance to Uni20','Distance to Uni21']]
Y = df['Price per sqm']

#with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  2.3313172945783425
# Coefficients:
#  [ 7.22419517e-04 -7.72492439e-03  1.24734985e-02 -8.53596231e-01
#   9.32162779e+03 -1.02535364e+03 -6.22931946e+03 -2.77300122e+01
#  -1.07754066e-01 -2.51422717e-01 -2.75913097e+05  3.70594545e+04
#   5.38133166e+04  5.38133165e+04  7.29457166e+03  2.20698172e+01
#   1.84831904e+04  4.70347037e+00  1.93592276e+03 -5.33167066e+04
#   8.99740055e+01  2.37520525e+05 -4.30873372e+04  6.46576099e+00
#   8.42232730e+04 -3.66824867e+01 -1.50897581e+01  2.37111631e+02
#   2.63430674e+01 -1.05685071e+05 -1.83629837e+04 -1.52409033e+02]

# %%
#Load data
data = pd.read_csv('alberlet_rent_houses_dis.csv')
df = pd.DataFrame(data, columns = ['ID', 'Apartment', 'House', 'Room', 'Price per month', 'Size(sqm)', 'Price per sqm', 'District I', 'District II','District III','District IV','District V','District VI','District VII','District VIII','District IX','District X','District XI','District XII','District XIII','District XIV','District XV','District XVI','District XVII','District XVIII','District XIX','District XX','District XXI','District XXII','District XXIII','Number of seperated rooms','Number of half rooms','Type of building: Castle, villa','Type of building: house','Type of the building: Part of house','Type of the building: Raw house','Type of building: Semi detached house','Deposit','Utilities','Common cost', 'Furniture: Empty', 'Furniture: Equipped', 'Furniture: Furnished', 'Furniture: Partly furnished', 'Floor', 'Balconies', 'View: Courtyard, sunny', 'View: Courtyard', 'View: Garden', 'View: Panoramic', 'View: Park', 'View: Street', 'View: Street, quiet', 'View: Street, sunny', 'View: City', 'View: Hills', 'Shortest rental period', 'Children welcomed', 'American kitchen', 'Can be an office', 'Foreigners welcomed', 'Washing machine', 'Latitude', 'Longitude', 'Postcode', 'Distace to Danube', 'Distace to City Centre','Distace to Keleti','Distace to Nyugati','Distance to Deli','Distance to Airport','Distance to Eco Zone','Distance to Crime Pot','Distance to Uni1','Distance to Uni2','Distance to Uni3','Distance to Uni4','Distance to Uni5','Distance to Uni6','Distance to Uni7','Distance to Uni8','Distance to Uni9','Distance to Uni10','Distance to Uni11','Distance to Uni12','Distance to Uni13','Distance to Uni14','Distance to Uni15','Distance to Uni16','Distance to Uni17','Distance to Uni18','Distance to Uni19','Distance to Uni20','Distance to Uni21'])

print(df)
# Out:
#     ID  Apartment  House  Room  Price per month  Size(sqm)  Price per sqm  \
# 0    0          0      1     0             1206        120      10.050000
# 1    1          0      1     0             1824        310       5.883871
# 2    2          0      1     0              448         77       5.818182
# 3    3          0      1     0              773         70      11.042857
# 4    4          0      1     0              556         80       6.950000
# 5    5          0      1     0              896        130       6.892308
# 6    6          0      1     0              155         30       5.166667
# 7    7          0      1     0              680         90       7.555556
# 8    8          0      1     0              182         50       3.640000
# 9    9          0      1     0              742        140       5.300000
# 10  10          0      1     0              464        130       3.569231
# 11  11          0      1     0               91          6      15.166667
# ...

# %%
X = df[['Deposit','Utilities','Common cost','Distace to Danube', 'Distace to City Centre','Distace to Keleti','Distace to Nyugati','Distance to Deli','Distance to Airport','Distance to Eco Zone','Distance to Crime Pot','Distance to Uni1','Distance to Uni2','Distance to Uni3','Distance to Uni4','Distance to Uni5','Distance to Uni6','Distance to Uni7','Distance to Uni8','Distance to Uni9','Distance to Uni10','Distance to Uni11','Distance to Uni12','Distance to Uni13','Distance to Uni14','Distance to Uni15','Distance to Uni16','Distance to Uni17','Distance to Uni18','Distance to Uni19','Distance to Uni20','Distance to Uni21']]
Y = df['Price per sqm']

#with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
