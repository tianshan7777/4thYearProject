# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#input data
albert_10min = pd.read_csv('./Data/10min/albert_10min.csv')
realRA_10min = pd.read_csv('./Data/10min/real_RA_10min.csv')
realRH_10min = pd.read_csv('./Data/10min/real_RH_10min.csv')

# %%
#Select columns
albert_price = albert_10min['price_per_sqm']
realRA_price = realRA_10min['price_per_sqm']
realRH_price = realRH_10min['price_per_sqm']

# %%
albert_price.describe()
# Out:
# count    3375.000000
# mean       11.209605
# std         4.127329
# min         0.000000
# 25%         8.553846
# 50%        10.425000
# 75%        12.682569
# max        79.528571
# Name: price_per_sqm, dtype: float64

# %%
realRA_price.describe()
# Out:
# count     7839.000000
# mean        20.845701
# std        326.981924
# min          0.172973
# 25%          9.000000
# 50%         10.996364
# 75%         13.622857
# max      15200.000000
# Name: price_per_sqm, dtype: float64

# %%
realRH_price.describe()
# Out:
# count    557.000000
# mean       9.764659
# std        5.102714
# min        1.440000
# 25%        6.895147
# 50%        9.272783
# 75%       11.525612
# max       89.600000
# Name: price_per_sqm, dtype: float64

# %%
plt.figure(figsize=(40,10))
plt.hist(albert_price, bins=300, alpha=0.5, label='alberlet')
plt.hist(realRA_price, bins=300, alpha=0.5, label='ingatlan_RA')
plt.hist(realRH_price, bins=300, alpha=0.5, label='ingatlan_RH')
plt.legend(loc='upper right')
plt.show()

plt.savefig('origin_data.png')

# %%
data = pd.read_csv('rent_origin.csv')

# %%
sns.boxplot(x = data['price_per_sqm'])
plt.savefig('origin_box.png')

# %%
plt.figure(figsize=(10,10))
plt.hist(data['price_per_sqm'], bins=500, alpha=0.5)
plt.xlabel('price_per_sqm')
plt.ylabel('frequency')
plt.show()
plt.savefig('origin_data_2.png')

# %%
data_clean = pd.read_csv('rent_clean.csv')
plt.figure(figsize=(10,10))
plt.hist(data_clean['price_per_sqm'], bins=300, alpha=0.5)
plt.xlabel('price_per_sqm')
plt.ylabel('frequency')
plt.show()
plt.savefig('clean_data_1.png')

# %%
sns.boxplot(x = data_clean['price_per_sqm'])
plt.savefig('clean_data_box.png')
