# %% [markdown]
# #This notebook is for bothe coe analysis and model building for extra features of properties

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
import pandas as pd
#OLS
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression, LassoLarsIC
import numpy as np
from IPython.display import HTML, display
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Load data
data = pd.read_csv('rent_clean.csv')
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (39,50,111) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Alberlet
# fit our model with .fit() and show results
# we use statsmodels' formula API to invoke the syntax below,
# where we write out the formula using ~
housing_model = ols("price_per_sqm ~ apartment + number_of_whole_rooms + number_of_half_rooms + floor + lift + air_conditioner + furnish_furnished + view_garden  + view_panoramic  + view_street + type_of_the_building_brick_apartment + type_of_the_building_block_apartment", data=data).fit()

# summarize our model
housing_model_summary = housing_model.summary()

# convert our table to HTML and add colors to headers for explanatory purposes
HTML(
(housing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>      <td>price_per_sqm</td>  <th>  R-squared:         </th> <td>   0.188</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th> <td>   0.153</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   5.430</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Fri, 19 Apr 2019</td> <th>  Prob (F-statistic):</th> <td>9.02e-08</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>20:03:13</td>     <th>  Log-Likelihood:    </th> <td> -738.10</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>   270</td>      <th>  AIC:               </th> <td>   1500.</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>   258</td>      <th>  BIC:               </th> <td>   1543.</td>
# </tr>
# <tr>
# ...

# %%
print(housing_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          price_per_sqm   R-squared:                       0.188
# Model:                            OLS   Adj. R-squared:                  0.153
# Method:                 Least Squares   F-statistic:                     5.430
# Date:                Fri, 19 Apr 2019   Prob (F-statistic):           9.02e-08
# Time:                        20:03:13   Log-Likelihood:                -738.10
# No. Observations:                 270   AIC:                             1500.
# Df Residuals:                     258   BIC:                             1543.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# ...

# %%
#Alberlet
# fit our model with .fit() and show results
# we use statsmodels' formula API to invoke the syntax below,
# where we write out the formula using ~
housing_model = ols("price_per_sqm ~ apartment + number_of_whole_rooms + number_of_half_rooms + floor + lift + air_conditioner + furnish_furnished + view_garden + view_panoramic + view_street + type_of_the_building_brick_apartment + type_of_the_building_block_apartment + utilities_fee_per_sqm", data=data).fit()

# summarize our model
housing_model_summary = housing_model.summary()

# convert our table to HTML and add colors to headers for explanatory purposes
HTML(
(housing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>      <td>price_per_sqm</td>  <th>  R-squared:         </th> <td>   0.229</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th> <td>   0.193</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   6.353</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Fri, 19 Apr 2019</td> <th>  Prob (F-statistic):</th> <td>7.47e-10</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>20:03:13</td>     <th>  Log-Likelihood:    </th> <td> -731.14</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>   270</td>      <th>  AIC:               </th> <td>   1488.</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>   257</td>      <th>  BIC:               </th> <td>   1535.</td>
# </tr>
# <tr>
# ...

# %%
print(housing_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          price_per_sqm   R-squared:                       0.229
# Model:                            OLS   Adj. R-squared:                  0.193
# Method:                 Least Squares   F-statistic:                     6.353
# Date:                Fri, 19 Apr 2019   Prob (F-statistic):           7.47e-10
# Time:                        20:03:15   Log-Likelihood:                -731.14
# No. Observations:                 270   AIC:                             1488.
# Df Residuals:                     257   BIC:                             1535.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# ...

# %%
#Alberlet
# fit our model with .fit() and show results
# we use statsmodels' formula API to invoke the syntax below,
# where we write out the formula using ~
housing_model = ols("price_per_sqm ~ apartment + number_of_whole_rooms + number_of_half_rooms + floor + lift + air_conditioner + furnish_furnished + view_garden + view_panoramic + view_street + type_of_the_building_brick_apartment + type_of_the_building_block_apartment + utilities_fee_per_sqm + furnish_equipped + furnish_partly_furnished + furnish_empty", data=data).fit()

# summarize our model
housing_model_summary = housing_model.summary()

# convert our table to HTML and add colors to headers for explanatory purposes
HTML(
(housing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>      <td>price_per_sqm</td>  <th>  R-squared:         </th> <td>   0.233</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th> <td>   0.187</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   5.133</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Fri, 19 Apr 2019</td> <th>  Prob (F-statistic):</th> <td>6.94e-09</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>20:03:16</td>     <th>  Log-Likelihood:    </th> <td> -730.47</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>   270</td>      <th>  AIC:               </th> <td>   1493.</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>   254</td>      <th>  BIC:               </th> <td>   1551.</td>
# </tr>
# <tr>
# ...

# %%
print(housing_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          price_per_sqm   R-squared:                       0.233
# Model:                            OLS   Adj. R-squared:                  0.187
# Method:                 Least Squares   F-statistic:                     5.133
# Date:                Fri, 19 Apr 2019   Prob (F-statistic):           6.94e-09
# Time:                        20:03:17   Log-Likelihood:                -730.47
# No. Observations:                 270   AIC:                             1493.
# Df Residuals:                     254   BIC:                             1551.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# ...

# %%
#Alberlet
# fit our model with .fit() and show results
# we use statsmodels' formula API to invoke the syntax below,
# where we write out the formula using ~
housing_model = ols("price_per_sqm ~ apartment + number_of_whole_rooms + number_of_half_rooms + floor + lift + air_conditioner + furnish_furnished + view_garden + view_panoramic + view_street + type_of_the_building_brick_apartment + type_of_the_building_block_apartment + utilities_fee_per_sqm + furnish_equipped + furnish_partly_furnished + furnish_empty + view_courtyard + view_courtyard_sunny + view_danube + view_roof + view_square + view_park + view_street_quiet + view_street_sunny + view_city + view_hill", data=data).fit()

# summarize our model
housing_model_summary = housing_model.summary()

# convert our table to HTML and add colors to headers for explanatory purposes
HTML(
(housing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>      <td>price_per_sqm</td>  <th>  R-squared:         </th> <td>   0.247</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th> <td>   0.169</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   3.193</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Fri, 19 Apr 2019</td> <th>  Prob (F-statistic):</th> <td>1.79e-06</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>20:03:17</td>     <th>  Log-Likelihood:    </th> <td> -728.00</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>   270</td>      <th>  AIC:               </th> <td>   1508.</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>   244</td>      <th>  BIC:               </th> <td>   1602.</td>
# </tr>
# <tr>
# ...

# %%
print(housing_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          price_per_sqm   R-squared:                       0.247
# Model:                            OLS   Adj. R-squared:                  0.169
# Method:                 Least Squares   F-statistic:                     3.193
# Date:                Fri, 19 Apr 2019   Prob (F-statistic):           1.79e-06
# Time:                        20:03:18   Log-Likelihood:                -728.00
# No. Observations:                 270   AIC:                             1508.
# Df Residuals:                     244   BIC:                             1602.
# Df Model:                          25
# Covariance Type:            nonrobust
# ...
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# ...

# %%
#Alberlet
# fit our model with .fit() and show results
# we use statsmodels' formula API to invoke the syntax below,
# where we write out the formula using ~
housing_model = ols("price_per_sqm ~ apartment + number_of_whole_rooms + number_of_half_rooms + floor + lift + air_conditioner + furnish_furnished + view_garden + view_panoramic + view_street + type_of_the_building_brick_apartment + type_of_the_building_block_apartment + utilities_fee_per_sqm + furnish_equipped + furnish_partly_furnished + furnish_empty + view_courtyard + view_courtyard_sunny + view_danube + view_roof + view_square + view_park + view_street_quiet + view_street_sunny + view_city + view_hill + balcony + children_welcomed + foreigners_welcomed + american_kitchen + pet", data=data).fit()

# summarize our model
housing_model_summary = housing_model.summary()

# convert our table to HTML and add colors to headers for explanatory purposes
HTML(
(housing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>      <td>price_per_sqm</td>  <th>  R-squared:         </th> <td>   0.362</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th> <td>   0.080</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   1.284</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Fri, 19 Apr 2019</td> <th>  Prob (F-statistic):</th>  <td> 0.208</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>20:03:18</td>     <th>  Log-Likelihood:    </th> <td> -224.87</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>    89</td>      <th>  AIC:               </th> <td>   505.7</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>    61</td>      <th>  BIC:               </th> <td>   575.4</td>
# </tr>
# <tr>
# ...

# %%
print(housing_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          price_per_sqm   R-squared:                       0.362
# Model:                            OLS   Adj. R-squared:                  0.080
# Method:                 Least Squares   F-statistic:                     1.284
# Date:                Fri, 19 Apr 2019   Prob (F-statistic):              0.208
# Time:                        20:03:19   Log-Likelihood:                -224.87
# No. Observations:                  89   AIC:                             505.7
# Df Residuals:                      61   BIC:                             575.4
# Df Model:                          27
# Covariance Type:            nonrobust
# ...
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# ...

# %%
#Alberlet
# fit our model with .fit() and show results
# we use statsmodels' formula API to invoke the syntax below,
# where we write out the formula using ~
housing_model = ols("price_per_sqm ~ apartment + number_of_whole_rooms + number_of_half_rooms + floor + lift + air_conditioner + furnish_furnished + view_garden  + view_panoramic  + view_street + condition_of_property_renovated + condition_of_property_newly_build + condition_of_property_in_good_condition + condition_of_property_in_medium_condition + condition_of_property_needs_renovation + condition_of_property_mint", data=data).fit()

# summarize our model
housing_model_summary = housing_model.summary()

# convert our table to HTML and add colors to headers for explanatory purposes
HTML(
(housing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>      <td>price_per_sqm</td>  <th>  R-squared:         </th> <td>   0.241</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th> <td>   0.238</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   76.28</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Fri, 19 Apr 2019</td> <th>  Prob (F-statistic):</th> <td>1.37e-202</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>20:03:19</td>     <th>  Log-Likelihood:    </th> <td> -10018.</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>  3614</td>      <th>  AIC:               </th> <td>2.007e+04</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>  3598</td>      <th>  BIC:               </th> <td>2.017e+04</td>
# </tr>
# <tr>
# ...

# %%
print(housing_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          price_per_sqm   R-squared:                       0.241
# Model:                            OLS   Adj. R-squared:                  0.238
# Method:                 Least Squares   F-statistic:                     76.28
# Date:                Fri, 19 Apr 2019   Prob (F-statistic):          1.37e-202
# Time:                        20:03:20   Log-Likelihood:                -10018.
# No. Observations:                3614   AIC:                         2.007e+04
# Df Residuals:                    3598   BIC:                         2.017e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# ...

# %%
#Alberlet
# fit our model with .fit() and show results
# we use statsmodels' formula API to invoke the syntax below,
# where we write out the formula using ~
housing_model = ols("price_per_sqm ~ apartment + number_of_whole_rooms + number_of_half_rooms + floor + lift + air_conditioner + furnish_furnished + view_garden  + view_panoramic  + view_street + condition_of_property_renovated + condition_of_property_newly_build + condition_of_property_in_good_condition + condition_of_property_in_medium_condition + condition_of_property_needs_renovation + condition_of_property_mint + energy_performance_certificate", data=data).fit()

# summarize our model
housing_model_summary = housing_model.summary()

# convert our table to HTML and add colors to headers for explanatory purposes
HTML(
(housing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>      <td>price_per_sqm</td>  <th>  R-squared:         </th> <td>   0.252</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th> <td>   0.227</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   10.15</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Fri, 19 Apr 2019</td> <th>  Prob (F-statistic):</th> <td>3.08e-22</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>20:03:21</td>     <th>  Log-Likelihood:    </th> <td> -1317.4</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>   499</td>      <th>  AIC:               </th> <td>   2669.</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>   482</td>      <th>  BIC:               </th> <td>   2740.</td>
# </tr>
# <tr>
# ...

# %%
print(housing_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          price_per_sqm   R-squared:                       0.252
# Model:                            OLS   Adj. R-squared:                  0.227
# Method:                 Least Squares   F-statistic:                     10.15
# Date:                Fri, 19 Apr 2019   Prob (F-statistic):           3.08e-22
# Time:                        20:03:21   Log-Likelihood:                -1317.4
# No. Observations:                 499   AIC:                             2669.
# Df Residuals:                     482   BIC:                             2740.
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# ...

# %%
#Alberlet
# fit our model with .fit() and show results
# we use statsmodels' formula API to invoke the syntax below,
# where we write out the formula using ~
housing_model = ols("price_per_sqm ~ apartment + number_of_whole_rooms + number_of_half_rooms + floor + lift + air_conditioner + furnish_furnished + view_garden  + view_panoramic  + view_street + condition_of_property_renovated + condition_of_property_newly_build + condition_of_property_in_good_condition + condition_of_property_in_medium_condition + condition_of_property_needs_renovation + condition_of_property_mint + energy_performance_certificate + orientation_north + orientation_south + orientation_east + orientation_west + orientation_northeast + orientation_northwest + orientation_southwest + orientation_southeast", data=data).fit()

# summarize our model
housing_model_summary = housing_model.summary()

# convert our table to HTML and add colors to headers for explanatory purposes
HTML(
(housing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>      <td>price_per_sqm</td>  <th>  R-squared:         </th> <td>   0.259</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th> <td>   0.221</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   6.898</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Fri, 19 Apr 2019</td> <th>  Prob (F-statistic):</th> <td>2.59e-19</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>20:03:22</td>     <th>  Log-Likelihood:    </th> <td> -1315.1</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>   499</td>      <th>  AIC:               </th> <td>   2680.</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>   474</td>      <th>  BIC:               </th> <td>   2786.</td>
# </tr>
# <tr>
# ...

# %%
print(housing_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          price_per_sqm   R-squared:                       0.259
# Model:                            OLS   Adj. R-squared:                  0.221
# Method:                 Least Squares   F-statistic:                     6.898
# Date:                Fri, 19 Apr 2019   Prob (F-statistic):           2.59e-19
# Time:                        20:03:22   Log-Likelihood:                -1315.1
# No. Observations:                 499   AIC:                             2680.
# Df Residuals:                     474   BIC:                             2786.
# Df Model:                          24
# Covariance Type:            nonrobust
# ...
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# ...

# %%
#Alberlet
# fit our model with .fit() and show results
# we use statsmodels' formula API to invoke the syntax below,
# where we write out the formula using ~
housing_model = ols("price_per_sqm ~ apartment + number_of_whole_rooms + number_of_half_rooms + floor + lift + air_conditioner + furnish_furnished + view_garden  + view_panoramic  + view_street + condition_of_property_renovated + condition_of_property_newly_build + condition_of_property_in_good_condition + condition_of_property_in_medium_condition + condition_of_property_needs_renovation + condition_of_property_mint + energy_performance_certificate + orientation_north + orientation_south + orientation_east + orientation_west + orientation_northeast + orientation_northwest + orientation_southwest + orientation_southeast + attic_loft_conversion + attic_penthouse + attic_topfloor", data=data).fit()

# summarize our model
housing_model_summary = housing_model.summary()

# convert our table to HTML and add colors to headers for explanatory purposes
HTML(
(housing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>      <td>price_per_sqm</td>  <th>  R-squared:         </th> <td>   0.261</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th> <td>   0.219</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   6.168</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Fri, 19 Apr 2019</td> <th>  Prob (F-statistic):</th> <td>2.45e-18</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>20:03:23</td>     <th>  Log-Likelihood:    </th> <td> -1314.3</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>   499</td>      <th>  AIC:               </th> <td>   2685.</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>   471</td>      <th>  BIC:               </th> <td>   2803.</td>
# </tr>
# <tr>
# ...

# %%
print(housing_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          price_per_sqm   R-squared:                       0.261
# Model:                            OLS   Adj. R-squared:                  0.219
# Method:                 Least Squares   F-statistic:                     6.168
# Date:                Fri, 19 Apr 2019   Prob (F-statistic):           2.45e-18
# Time:                        20:03:23   Log-Likelihood:                -1314.3
# No. Observations:                 499   AIC:                             2685.
# Df Residuals:                     471   BIC:                             2803.
# Df Model:                          27
# Covariance Type:            nonrobust
# ...
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# ...
