# %%
#Feature selected according to random forest tree
import pandas as pd
from sklearn.model_selection import KFold
#OLS
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
#Load data
data = pd.read_csv('rent_clean.csv')
test = data[['price_per_sqm', 'apartment', 'house', 'number_of_whole_rooms', 'floor', 'number_of_half_rooms', 'furnish_furnished', 'furnish_partly_furnished', 'view_garden', 'view_panoramic', 'view_street', 'balcony', 'lift', 'air_conditioner', 'utility_double_comfort', 'heating_gas', 'heating_wall_heating', 'heating_combination', 'heating_ceiling', 'heating_central_heating', 'heating_electric', 'heating_floor', 'heating_circulating', 'heating_district', 'available_immediately', 'condition_of_property_renovated', 'parking']]
test = test.dropna()
test.head()
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (39,50,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     price_per_sqm  apartment  house  number_of_whole_rooms  floor  \
# 9       10.725806          1      0                    2.0    1.0
# 37      11.166667          1      0                    1.0    2.0
# 44       7.584906          1      0                    1.0    3.0
# 45      15.000000          1      0                    3.0    3.0
# 49       9.763158          1      0                    1.0    4.0
#
#     number_of_half_rooms  furnish_furnished  furnish_partly_furnished  \
# 9                    0.0                1.0                       0.0
# 37                   0.0                0.0                       1.0
# 44                   0.0                1.0                       0.0
# 45                   0.0                0.0                       1.0
# 49                   0.0                1.0                       0.0
#
#     view_garden  view_panoramic   ...     heating_combination  \
# 9             0               0   ...                       0
# 37            0               0   ...                       0
# 44            0               0   ...                       0
# 45            0               0   ...                       0
# 49            0               0   ...                       0
#
#     heating_ceiling  heating_central_heating  heating_electric  heating_floor  \
# 9                 0                        0               0.0            0.0
# 37                0                        0               0.0            0.0
# 44                0                        0               0.0            0.0
# 45                0                        0               1.0            0.0
# 49                0                        0               0.0            0.0
#
#     heating_circulating  heating_district  available_immediately  \
# 9                   0.0               0.0                    1.0
# 37                  0.0               0.0                    1.0
# 44                  0.0               0.0                    1.0
# 45                  0.0               0.0                    0.0
# 49                  0.0               0.0                    1.0
#
#     condition_of_property_renovated  parking
# 9                                 1      1.0
# 37                                0      0.0
# 44                                0      0.0
# 45                                0      1.0
# 49                                0      1.0
#
# [5 rows x 27 columns]

# %%
#15 features
X = test[['floor','number_of_whole_rooms','air_conditioner','number_of_half_rooms','available_immediately','furnish_furnished','lift','condition_of_property_renovated','utility_double_comfort','view_street','heating_central_heating','heating_combination','view_panoramic','balcony','view_garden']]
y = test[['price_per_sqm']]

# %%
#10 fold
scores = []
cv = KFold(n_splits = 10, random_state = 42, shuffle = False)
for train_index, test_index in cv.split(X):
    #print('Train Index:', train_index, '\n')
    #print('Test Index:', test_index)
    
    X_train, X_test, y_train, y_test = X.iloc[train_index.tolist()], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
    my_model = LinearRegression().fit(X_train, y_train)
    scores.append(my_model.score(X_test, y_test))

r_square = np.mean(scores)
adj_r = 1-(1-r_square)*(len(y)-1)/(len(y)-X.shape[1]-1)

print('R Square:', r_square, '\n')
print('Adjusted R Square:', adj_r, '\n')
# Out:
# R Square: 0.14414834188089978
#
# Adjusted R Square: 0.1338368761204286
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/base.py:485: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   linalg.lstsq(X, y)

# %%
#20 features
X = test[['floor','number_of_whole_rooms','air_conditioner','number_of_half_rooms','available_immediately','furnish_furnished','lift','condition_of_property_renovated','utility_double_comfort','view_street','heating_central_heating','heating_combination','view_panoramic','balcony','view_garden','heating_circulating','heating_district','parking','heating_gas', 'heating_electric']]
y = test[['price_per_sqm']]

# %%
#10 fold
scores = []
cv = KFold(n_splits = 10, random_state = 42, shuffle = False)
for train_index, test_index in cv.split(X):
    #print('Train Index:', train_index, '\n')
    #print('Test Index:', test_index)
    
    X_train, X_test, y_train, y_test = X.iloc[train_index.tolist()], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
    my_model = LinearRegression().fit(X_train, y_train)
    scores.append(my_model.score(X_test, y_test))

r_square = np.mean(scores)
adj_r = 1-(1-r_square)*(len(y)-1)/(len(y)-X.shape[1]-1)

print('R Square:', r_square, '\n')
print('Adjusted R Square:', adj_r, '\n')
# Out:
# R Square: 0.17807198528199153
#
# Adjusted R Square: 0.16481508181879778
