# %% [markdown]
# This is a notebook for robustness check on upper and lower 25% of the data

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
import pandas as pd
#OLS
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression, LassoLarsIC
import numpy as np
from IPython.display import HTML, display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Load data
data = pd.read_csv('rent_0.25.csv')

# %%
housing_model = ols("price_per_sqm ~ apartment + number_of_whole_rooms + number_of_half_rooms + floor", data=data).fit()

# summarize our model
housing_model_summary = housing_model.summary()

# convert our table to HTML and add colors to headers for explanatory purposes
HTML(
(housing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>      <td>price_per_sqm</td>  <th>  R-squared:         </th> <td>   0.029</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th> <td>   0.028</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   19.29</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Fri, 19 Apr 2019</td> <th>  Prob (F-statistic):</th> <td>1.20e-15</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>20:13:48</td>     <th>  Log-Likelihood:    </th> <td> -7243.4</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>  2583</td>      <th>  AIC:               </th> <td>1.450e+04</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>  2578</td>      <th>  BIC:               </th> <td>1.453e+04</td>
# </tr>
# <tr>
# ...

# %%
print(housing_model_summary)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          price_per_sqm   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.028
# Method:                 Least Squares   F-statistic:                     19.29
# Date:                Fri, 19 Apr 2019   Prob (F-statistic):           1.20e-15
# Time:                        20:13:48   Log-Likelihood:                -7243.4
# No. Observations:                2583   AIC:                         1.450e+04
# Df Residuals:                    2578   BIC:                         1.453e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                13.2895      1.376      9.655      0.000      10.591      15.988
# ...

# %%
# basic specifications + basic decorations 
# fit our model with .fit() and show results
# we use statsmodels' formula API to invoke the syntax below,
# where we write out the formula using ~
housing_model = ols("price_per_sqm ~ apartment + number_of_whole_rooms + number_of_half_rooms + floor + lift + air_conditioner + furnish_furnished", data=data).fit()

# summarize our model
housing_model_summary = housing_model.summary()

# convert our table to HTML and add colors to headers for explanatory purposes
HTML(
(housing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>      <td>price_per_sqm</td>  <th>  R-squared:         </th> <td>   0.069</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th> <td>   0.064</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   15.07</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Fri, 19 Apr 2019</td> <th>  Prob (F-statistic):</th> <td>1.08e-16</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>20:13:49</td>     <th>  Log-Likelihood:    </th> <td> -3427.5</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>  1227</td>      <th>  AIC:               </th> <td>   6869.</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>  1220</td>      <th>  BIC:               </th> <td>   6905.</td>
# </tr>
# <tr>
# ...

# %%
print(housing_model_summary)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          price_per_sqm   R-squared:                       0.069
# Model:                            OLS   Adj. R-squared:                  0.064
# Method:                 Least Squares   F-statistic:                     15.07
# Date:                Fri, 19 Apr 2019   Prob (F-statistic):           1.08e-16
# Time:                        20:13:49   Log-Likelihood:                -3427.5
# No. Observations:                1227   AIC:                             6869.
# Df Residuals:                    1220   BIC:                             6905.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 6.8466      0.229     29.911      0.000       6.398       7.296
# ...

# %%
# basic specifications + basic decoration + basic view
# fit our model with .fit() and show results
# we use statsmodels' formula API to invoke the syntax below,
# where we write out the formula using ~
housing_model = ols("price_per_sqm ~ apartment + number_of_whole_rooms + number_of_half_rooms + floor + lift + air_conditioner + furnish_furnished + view_garden + view_panoramic + view_street", data=data).fit()

# summarize our model
housing_model_summary = housing_model.summary()

# convert our table to HTML and add colors to headers for explanatory purposes
HTML(
(housing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>      <td>price_per_sqm</td>  <th>  R-squared:         </th> <td>   0.073</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th> <td>   0.066</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   10.69</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Fri, 19 Apr 2019</td> <th>  Prob (F-statistic):</th> <td>4.29e-16</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>20:13:51</td>     <th>  Log-Likelihood:    </th> <td> -3424.7</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>  1227</td>      <th>  AIC:               </th> <td>   6869.</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>  1217</td>      <th>  BIC:               </th> <td>   6920.</td>
# </tr>
# <tr>
# ...

# %%
print(housing_model_summary)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          price_per_sqm   R-squared:                       0.073
# Model:                            OLS   Adj. R-squared:                  0.066
# Method:                 Least Squares   F-statistic:                     10.69
# Date:                Fri, 19 Apr 2019   Prob (F-statistic):           4.29e-16
# Time:                        20:13:51   Log-Likelihood:                -3424.7
# No. Observations:                1227   AIC:                             6869.
# Df Residuals:                    1217   BIC:                             6920.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 6.8861      0.288     23.925      0.000       6.321       7.451
# ...

# %%
# basic specifications + basic decoration + basic view + district
# fit our model with .fit() and show results
# we use statsmodels' formula API to invoke the syntax below,
# where we write out the formula using ~
housing_model = ols("price_per_sqm ~ apartment + number_of_whole_rooms + number_of_half_rooms + floor + lift + air_conditioner + furnish_furnished + view_garden + view_panoramic + view_street + district_i + district_ii + district_iii + district_iv + district_v + district_vi + district_vii + district_viii + district_ix + district_x + district_xi + district_xii + district_xiii + district_xiv + district_xv + district_xvi + district_xvii + district_xviii + district_xix + district_xx + district_xxi + district_xxii + district_xxiii", data=data).fit()

# summarize our model
housing_model_summary = housing_model.summary()

# convert our table to HTML and add colors to headers for explanatory purposes
HTML(
(housing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# /usr/local/lib/python3.7/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# /usr/local/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /usr/local/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /usr/local/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>      <td>price_per_sqm</td>  <th>  R-squared:         </th> <td>   0.113</td>
# </tr>
# <tr>
# ...

# %%
print(housing_model_summary)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          price_per_sqm   R-squared:                       0.113
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     6.398
# Date:                Fri, 19 Apr 2019   Prob (F-statistic):           1.97e-19
# Time:                        20:13:52   Log-Likelihood:                -3397.6
# No. Observations:                1227   AIC:                             6845.
# Df Residuals:                    1202   BIC:                             6973.
# Df Model:                          24
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 6.5093      0.310     20.969      0.000       5.900       7.118
# ...

# %%
# basic specifications + basic decoration + basic view + district + heating 
# fit our model with .fit() and show results
# we use statsmodels' formula API to invoke the syntax below,
# where we write out the formula using ~
housing_model = ols("price_per_sqm ~ apartment + number_of_whole_rooms + number_of_half_rooms + floor + lift + air_conditioner + furnish_furnished + view_garden + view_panoramic + view_street + district_i + district_ii + district_iii + district_iv + district_v + district_vi + district_vii + district_viii + district_ix + district_x + district_xi + district_xii + district_xiii + district_xiv + district_xv + district_xvi + district_xvii + district_xviii + district_xix + district_xx + district_xxi + district_xxii + district_xxiii + heating_gas + heating_wall_heating + heating_combination + heating_ceiling + heating_central_heating + heating_electric + heating_floor + heating_circulating + heating_district", data=data).fit()

# summarize our model
housing_model_summary = housing_model.summary()

# convert our table to HTML and add colors to headers for explanatory purposes
HTML(
(housing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>      <td>price_per_sqm</td>  <th>  R-squared:         </th> <td>   0.135</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th> <td>   0.112</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   5.664</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Fri, 19 Apr 2019</td> <th>  Prob (F-statistic):</th> <td>2.05e-21</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>20:13:53</td>     <th>  Log-Likelihood:    </th> <td> -3382.1</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>  1227</td>      <th>  AIC:               </th> <td>   6832.</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>  1193</td>      <th>  BIC:               </th> <td>   7006.</td>
# </tr>
# <tr>
# ...

# %%
print(housing_model_summary)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          price_per_sqm   R-squared:                       0.135
# Model:                            OLS   Adj. R-squared:                  0.112
# Method:                 Least Squares   F-statistic:                     5.664
# Date:                Fri, 19 Apr 2019   Prob (F-statistic):           2.05e-21
# Time:                        20:13:53   Log-Likelihood:                -3382.1
# No. Observations:                1227   AIC:                             6832.
# Df Residuals:                    1193   BIC:                             7006.
# Df Model:                          33
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   6.7416      0.336     20.042      0.000       6.082       7.402
# ...

# %%
#Load data
data = pd.read_csv('rent_0.75.csv')

# %%
housing_model = ols("price_per_sqm ~ apartment + number_of_whole_rooms + number_of_half_rooms + floor", data=data).fit()

# summarize our model
housing_model_summary = housing_model.summary()

# convert our table to HTML and add colors to headers for explanatory purposes
HTML(
(housing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>      <td>price_per_sqm</td>  <th>  R-squared:         </th> <td>   0.034</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th> <td>   0.032</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   19.52</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Sat, 20 Apr 2019</td> <th>  Prob (F-statistic):</th> <td>8.30e-16</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>01:43:58</td>     <th>  Log-Likelihood:    </th> <td> -3052.1</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>  2244</td>      <th>  AIC:               </th> <td>   6114.</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>  2239</td>      <th>  BIC:               </th> <td>   6143.</td>
# </tr>
# <tr>
# ...

# %%
print(housing_model_summary)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          price_per_sqm   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     19.52
# Date:                Sat, 20 Apr 2019   Prob (F-statistic):           8.30e-16
# Time:                        01:43:58   Log-Likelihood:                -3052.1
# No. Observations:                2244   AIC:                             6114.
# Df Residuals:                    2239   BIC:                             6143.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 6.7696      0.166     40.862      0.000       6.445       7.094
# ...

# %%
housing_model = ols("price_per_sqm ~ apartment + number_of_whole_rooms + number_of_half_rooms + floor + lift + air_conditioner + furnish_furnished", data=data).fit()

# summarize our model
housing_model_summary = housing_model.summary()

# convert our table to HTML and add colors to headers for explanatory purposes
HTML(
(housing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>      <td>price_per_sqm</td>  <th>  R-squared:         </th> <td>   0.089</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th> <td>   0.082</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   12.10</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Sat, 20 Apr 2019</td> <th>  Prob (F-statistic):</th> <td>5.30e-13</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>01:43:59</td>     <th>  Log-Likelihood:    </th> <td> -942.49</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>   749</td>      <th>  AIC:               </th> <td>   1899.</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>   742</td>      <th>  BIC:               </th> <td>   1931.</td>
# </tr>
# <tr>
# ...

# %%
print(housing_model_summary)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          price_per_sqm   R-squared:                       0.089
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     12.10
# Date:                Sat, 20 Apr 2019   Prob (F-statistic):           5.30e-13
# Time:                        01:43:59   Log-Likelihood:                -942.49
# No. Observations:                 749   AIC:                             1899.
# Df Residuals:                     742   BIC:                             1931.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 4.0208      0.058     68.795      0.000       3.906       4.136
# ...

# %%
# basic specifications + basic decoration + basic view
# fit our model with .fit() and show results
# we use statsmodels' formula API to invoke the syntax below,
# where we write out the formula using ~
housing_model = ols("price_per_sqm ~ apartment + number_of_whole_rooms + number_of_half_rooms + floor + lift + air_conditioner + furnish_furnished + view_garden + view_panoramic + view_street", data=data).fit()

# summarize our model
housing_model_summary = housing_model.summary()

# convert our table to HTML and add colors to headers for explanatory purposes
HTML(
(housing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>      <td>price_per_sqm</td>  <th>  R-squared:         </th> <td>   0.092</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th> <td>   0.081</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   8.285</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Sat, 20 Apr 2019</td> <th>  Prob (F-statistic):</th> <td>8.19e-12</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>01:44:00</td>     <th>  Log-Likelihood:    </th> <td> -941.45</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>   749</td>      <th>  AIC:               </th> <td>   1903.</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>   739</td>      <th>  BIC:               </th> <td>   1949.</td>
# </tr>
# <tr>
# ...

# %%
print(housing_model_summary)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          price_per_sqm   R-squared:                       0.092
# Model:                            OLS   Adj. R-squared:                  0.081
# Method:                 Least Squares   F-statistic:                     8.285
# Date:                Sat, 20 Apr 2019   Prob (F-statistic):           8.19e-12
# Time:                        01:44:00   Log-Likelihood:                -941.45
# No. Observations:                 749   AIC:                             1903.
# Df Residuals:                     739   BIC:                             1949.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 4.0794      0.078     52.126      0.000       3.926       4.233
# ...

# %%
# basic specifications + basic decoration + basic view + district
# fit our model with .fit() and show results
# we use statsmodels' formula API to invoke the syntax below,
# where we write out the formula using ~
housing_model = ols("price_per_sqm ~ apartment + number_of_whole_rooms + number_of_half_rooms + floor + lift + air_conditioner + furnish_furnished + view_garden + view_panoramic + view_street + district_i + district_ii + district_iii + district_iv + district_v + district_vi + district_vii + district_viii + district_ix + district_x + district_xi + district_xii + district_xiii + district_xiv + district_xv + district_xvi + district_xvii + district_xviii + district_xix + district_xx + district_xxi + district_xxii + district_xxiii", data=data).fit()

# summarize our model
housing_model_summary = housing_model.summary()

# convert our table to HTML and add colors to headers for explanatory purposes
HTML(
(housing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>      <td>price_per_sqm</td>  <th>  R-squared:         </th> <td>   0.171</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th> <td>   0.136</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   4.785</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Sat, 20 Apr 2019</td> <th>  Prob (F-statistic):</th> <td>2.28e-15</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>01:44:00</td>     <th>  Log-Likelihood:    </th> <td> -907.03</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>   749</td>      <th>  AIC:               </th> <td>   1878.</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>   717</td>      <th>  BIC:               </th> <td>   2026.</td>
# </tr>
# <tr>
# ...

# %%
print(housing_model_summary)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          price_per_sqm   R-squared:                       0.171
# Model:                            OLS   Adj. R-squared:                  0.136
# Method:                 Least Squares   F-statistic:                     4.785
# Date:                Sat, 20 Apr 2019   Prob (F-statistic):           2.28e-15
# Time:                        01:44:00   Log-Likelihood:                -907.03
# No. Observations:                 749   AIC:                             1878.
# Df Residuals:                     717   BIC:                             2026.
# Df Model:                          31
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 3.9924      0.076     52.201      0.000       3.842       4.143
# ...

# %%
# basic specifications + basic decoration + basic view + district + heating 
# fit our model with .fit() and show results
# we use statsmodels' formula API to invoke the syntax below,
# where we write out the formula using ~
housing_model = ols("price_per_sqm ~ apartment + number_of_whole_rooms + number_of_half_rooms + floor + lift + air_conditioner + furnish_furnished + view_garden + view_panoramic + view_street + district_i + district_ii + district_iii + district_iv + district_v + district_vi + district_vii + district_viii + district_ix + district_x + district_xi + district_xii + district_xiii + district_xiv + district_xv + district_xvi + district_xvii + district_xviii + district_xix + district_xx + district_xxi + district_xxii + district_xxiii + heating_gas + heating_wall_heating + heating_combination + heating_ceiling + heating_central_heating + heating_electric + heating_floor + heating_circulating + heating_district", data=data).fit()

# summarize our model
housing_model_summary = housing_model.summary()

# convert our table to HTML and add colors to headers for explanatory purposes
HTML(
(housing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>      <td>price_per_sqm</td>  <th>  R-squared:         </th> <td>   0.186</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th> <td>   0.142</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   4.165</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Sat, 20 Apr 2019</td> <th>  Prob (F-statistic):</th> <td>6.27e-15</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>01:44:01</td>     <th>  Log-Likelihood:    </th> <td> -900.20</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>   749</td>      <th>  AIC:               </th> <td>   1880.</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>   709</td>      <th>  BIC:               </th> <td>   2065.</td>
# </tr>
# <tr>
# ...

# %%
print(housing_model_summary)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          price_per_sqm   R-squared:                       0.186
# Model:                            OLS   Adj. R-squared:                  0.142
# Method:                 Least Squares   F-statistic:                     4.165
# Date:                Sat, 20 Apr 2019   Prob (F-statistic):           6.27e-15
# Time:                        01:44:01   Log-Likelihood:                -900.20
# No. Observations:                 749   AIC:                             1880.
# Df Residuals:                     709   BIC:                             2065.
# Df Model:                          39
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   3.9710      0.089     44.624      0.000       3.796       4.146
# ...
