# %% [markdown]
# #This notebook is for analysing coefficients table for basic features

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
import pandas as pd
#OLS
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression, LassoLarsIC
import numpy as np
from IPython.display import HTML, display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Load data
data = pd.read_csv('rent_clean.csv')
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (39,50,111) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# basic specifications
# fit our model with .fit() and show results
# we use statsmodels' formula API to invoke the syntax below,
# where we write out the formula using ~
housing_model = ols("price_per_sqm ~ apartment + number_of_whole_rooms + number_of_half_rooms + floor", data=data).fit()

# summarize our model
housing_model_summary = housing_model.summary()

# convert our table to HTML and add colors to headers for explanatory purposes
HTML(
(housing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>      <td>price_per_sqm</td>  <th>  R-squared:         </th> <td>   0.027</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th> <td>   0.026</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   66.96</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Fri, 19 Apr 2019</td> <th>  Prob (F-statistic):</th> <td>5.56e-56</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>14:59:39</td>     <th>  Log-Likelihood:    </th> <td> -27654.</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>  9759</td>      <th>  AIC:               </th> <td>5.532e+04</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>  9754</td>      <th>  BIC:               </th> <td>5.535e+04</td>
# </tr>
# <tr>
#   <th>Df Model:</th>              <td>     4</td>      <th>                     </th>     <td> </td>
# </tr>
# <tr>
#   <th>Covariance Type:</th>      <td>nonrobust</td>    <th>                     </th>     <td> </td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#             <td></td>               <th style="background-color:#ffbb78;">coef</th>     <th style="background-color:#c7e9c0;">std err</th>      <th>t</th>      <th style="background-color:#bcbddc;">P>|t|</th>  <th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>
# </tr>
# <tr>
#   <th>Intercept</th>             <td>    7.5535</td> <td>    0.478</td> <td>   15.789</td> <td> 0.000</td> <td>    6.616</td> <td>    8.491</td>
# </tr>
# <tr>
#   <th>apartment</th>             <td>    3.4394</td> <td>    0.454</td> <td>    7.571</td> <td> 0.000</td> <td>    2.549</td> <td>    4.330</td>
# </tr>
# <tr>
#   <th>number_of_whole_rooms</th> <td>    0.3656</td> <td>    0.044</td> <td>    8.383</td> <td> 0.000</td> <td>    0.280</td> <td>    0.451</td>
# </tr>
# <tr>
#   <th>number_of_half_rooms</th>  <td>   -0.6910</td> <td>    0.080</td> <td>   -8.674</td> <td> 0.000</td> <td>   -0.847</td> <td>   -0.535</td>
# </tr>
# <tr>
#   <th>floor</th>                 <td>    0.1015</td> <td>    0.020</td> <td>    5.098</td> <td> 0.000</td> <td>    0.062</td> <td>    0.141</td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#   <th>Omnibus:</th>       <td>3759.012</td> <th>  Durbin-Watson:     </th> <td>   1.830</td>
# </tr>
# <tr>
#   <th>Prob(Omnibus):</th>  <td> 0.000</td>  <th>  Jarque-Bera (JB):  </th> <td>22684.120</td>
# </tr>
# <tr>
#   <th>Skew:</th>           <td> 1.736</td>  <th>  Prob(JB):          </th> <td>    0.00</td>
# </tr>
# <tr>
#   <th>Kurtosis:</th>       <td> 9.613</td>  <th>  Cond. No.          </th> <td>    61.3</td>
# </tr>
# </table><br/><br/>Warnings:<br/>[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print(housing_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          price_per_sqm   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     66.96
# Date:                Fri, 19 Apr 2019   Prob (F-statistic):           5.56e-56
# Time:                        14:59:40   Log-Likelihood:                -27654.
# No. Observations:                9759   AIC:                         5.532e+04
# Df Residuals:                    9754   BIC:                         5.535e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 7.5535      0.478     15.789      0.000       6.616       8.491
# apartment                 3.4394      0.454      7.571      0.000       2.549       4.330
# number_of_whole_rooms     0.3656      0.044      8.383      0.000       0.280       0.451
# number_of_half_rooms     -0.6910      0.080     -8.674      0.000      -0.847      -0.535
# floor                     0.1015      0.020      5.098      0.000       0.062       0.141
# ==============================================================================
# Omnibus:                     3759.012   Durbin-Watson:                   1.830
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22684.120
# Skew:                           1.736   Prob(JB):                         0.00
# Kurtosis:                       9.613   Cond. No.                         61.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# basic specifications + basic decorations 
# fit our model with .fit() and show results
# we use statsmodels' formula API to invoke the syntax below,
# where we write out the formula using ~
housing_model = ols("price_per_sqm ~ apartment + number_of_whole_rooms + number_of_half_rooms + floor + lift + air_conditioner + furnish_furnished", data=data).fit()

# summarize our model
housing_model_summary = housing_model.summary()

# convert our table to HTML and add colors to headers for explanatory purposes
HTML(
(housing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>      <td>price_per_sqm</td>  <th>  R-squared:         </th> <td>   0.192</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th> <td>   0.190</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   131.2</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Fri, 19 Apr 2019</td> <th>  Prob (F-statistic):</th> <td>8.10e-174</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>14:59:40</td>     <th>  Log-Likelihood:    </th> <td> -10873.</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>  3884</td>      <th>  AIC:               </th> <td>2.176e+04</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>  3876</td>      <th>  BIC:               </th> <td>2.181e+04</td>
# </tr>
# <tr>
#   <th>Df Model:</th>              <td>     7</td>      <th>                     </th>     <td> </td>
# </tr>
# <tr>
#   <th>Covariance Type:</th>      <td>nonrobust</td>    <th>                     </th>     <td> </td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#             <td></td>               <th style="background-color:#ffbb78;">coef</th>     <th style="background-color:#c7e9c0;">std err</th>      <th>t</th>      <th style="background-color:#bcbddc;">P>|t|</th>  <th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>
# </tr>
# <tr>
#   <th>Intercept</th>             <td>    7.5150</td> <td>    2.335</td> <td>    3.218</td> <td> 0.001</td> <td>    2.936</td> <td>   12.094</td>
# </tr>
# <tr>
#   <th>apartment</th>             <td>    1.2193</td> <td>    2.316</td> <td>    0.527</td> <td> 0.599</td> <td>   -3.321</td> <td>    5.759</td>
# </tr>
# <tr>
#   <th>number_of_whole_rooms</th> <td>    0.2682</td> <td>    0.071</td> <td>    3.772</td> <td> 0.000</td> <td>    0.129</td> <td>    0.408</td>
# </tr>
# <tr>
#   <th>number_of_half_rooms</th>  <td>   -0.7394</td> <td>    0.123</td> <td>   -6.022</td> <td> 0.000</td> <td>   -0.980</td> <td>   -0.499</td>
# </tr>
# <tr>
#   <th>floor</th>                 <td>   -0.0971</td> <td>    0.036</td> <td>   -2.719</td> <td> 0.007</td> <td>   -0.167</td> <td>   -0.027</td>
# </tr>
# <tr>
#   <th>lift</th>                  <td>    1.5103</td> <td>    0.153</td> <td>    9.894</td> <td> 0.000</td> <td>    1.211</td> <td>    1.810</td>
# </tr>
# <tr>
#   <th>air_conditioner</th>       <td>    2.6617</td> <td>    0.140</td> <td>   18.967</td> <td> 0.000</td> <td>    2.387</td> <td>    2.937</td>
# </tr>
# <tr>
#   <th>furnish_furnished</th>     <td>    1.4416</td> <td>    0.137</td> <td>   10.517</td> <td> 0.000</td> <td>    1.173</td> <td>    1.710</td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#   <th>Omnibus:</th>       <td>1208.688</td> <th>  Durbin-Watson:     </th> <td>   1.897</td>
# </tr>
# <tr>
#   <th>Prob(Omnibus):</th>  <td> 0.000</td>  <th>  Jarque-Bera (JB):  </th> <td>5225.850</td>
# </tr>
# <tr>
#   <th>Skew:</th>           <td> 1.459</td>  <th>  Prob(JB):          </th> <td>    0.00</td>
# </tr>
# <tr>
#   <th>Kurtosis:</th>       <td> 7.876</td>  <th>  Cond. No.          </th> <td>    214.</td>
# </tr>
# </table><br/><br/>Warnings:<br/>[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print(housing_model.summary())

# %%
# basic specifications + basic decoration + basic view
# fit our model with .fit() and show results
# we use statsmodels' formula API to invoke the syntax below,
# where we write out the formula using ~
housing_model = ols("price_per_sqm ~ apartment + number_of_whole_rooms + number_of_half_rooms + floor + lift + air_conditioner + furnish_furnished + view_garden + view_panoramic + view_street", data=data).fit()

# summarize our model
housing_model_summary = housing_model.summary()

# convert our table to HTML and add colors to headers for explanatory purposes
HTML(
(housing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>      <td>price_per_sqm</td>  <th>  R-squared:         </th> <td>   0.204</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th> <td>   0.202</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   99.21</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Tue, 16 Apr 2019</td> <th>  Prob (F-statistic):</th> <td>1.61e-183</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>07:01:49</td>     <th>  Log-Likelihood:    </th> <td> -10843.</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>  3884</td>      <th>  AIC:               </th> <td>2.171e+04</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>  3873</td>      <th>  BIC:               </th> <td>2.178e+04</td>
# </tr>
# <tr>
#   <th>Df Model:</th>              <td>    10</td>      <th>                     </th>     <td> </td>
# </tr>
# <tr>
#   <th>Covariance Type:</th>      <td>nonrobust</td>    <th>                     </th>     <td> </td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#             <td></td>               <th style="background-color:#ffbb78;">coef</th>     <th style="background-color:#c7e9c0;">std err</th>      <th>t</th>      <th style="background-color:#bcbddc;">P>|t|</th>  <th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>
# </tr>
# <tr>
#   <th>Intercept</th>             <td>    7.4605</td> <td>    2.332</td> <td>    3.199</td> <td> 0.001</td> <td>    2.888</td> <td>   12.033</td>
# </tr>
# <tr>
#   <th>apartment</th>             <td>    1.4430</td> <td>    2.301</td> <td>    0.627</td> <td> 0.531</td> <td>   -3.069</td> <td>    5.955</td>
# </tr>
# <tr>
#   <th>number_of_whole_rooms</th> <td>    0.1945</td> <td>    0.072</td> <td>    2.702</td> <td> 0.007</td> <td>    0.053</td> <td>    0.336</td>
# </tr>
# <tr>
#   <th>number_of_half_rooms</th>  <td>   -0.7711</td> <td>    0.122</td> <td>   -6.316</td> <td> 0.000</td> <td>   -1.011</td> <td>   -0.532</td>
# </tr>
# <tr>
#   <th>floor</th>                 <td>   -0.1618</td> <td>    0.037</td> <td>   -4.372</td> <td> 0.000</td> <td>   -0.234</td> <td>   -0.089</td>
# </tr>
# <tr>
#   <th>lift</th>                  <td>    1.6742</td> <td>    0.153</td> <td>   10.942</td> <td> 0.000</td> <td>    1.374</td> <td>    1.974</td>
# </tr>
# <tr>
#   <th>air_conditioner</th>       <td>    2.5117</td> <td>    0.141</td> <td>   17.827</td> <td> 0.000</td> <td>    2.235</td> <td>    2.788</td>
# </tr>
# <tr>
#   <th>furnish_furnished</th>     <td>    1.5203</td> <td>    0.137</td> <td>   11.134</td> <td> 0.000</td> <td>    1.253</td> <td>    1.788</td>
# </tr>
# <tr>
#   <th>view_garden</th>           <td>    0.1154</td> <td>    0.230</td> <td>    0.501</td> <td> 0.616</td> <td>   -0.336</td> <td>    0.567</td>
# </tr>
# <tr>
#   <th>view_panoramic</th>        <td>    0.9902</td> <td>    0.242</td> <td>    4.099</td> <td> 0.000</td> <td>    0.517</td> <td>    1.464</td>
# </tr>
# <tr>
#   <th>view_street</th>           <td>   -0.4058</td> <td>    0.221</td> <td>   -1.836</td> <td> 0.066</td> <td>   -0.839</td> <td>    0.027</td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#   <th>Omnibus:</th>       <td>1225.532</td> <th>  Durbin-Watson:     </th> <td>   1.891</td>
# </tr>
# <tr>
#   <th>Prob(Omnibus):</th>  <td> 0.000</td>  <th>  Jarque-Bera (JB):  </th> <td>5420.430</td>
# </tr>
# <tr>
#   <th>Skew:</th>           <td> 1.473</td>  <th>  Prob(JB):          </th> <td>    0.00</td>
# </tr>
# <tr>
#   <th>Kurtosis:</th>       <td> 7.982</td>  <th>  Cond. No.          </th> <td>    216.</td>
# </tr>
# </table><br/><br/>Warnings:<br/>[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print(housing_model.summary())

# %%
# basic specifications + basic decoration + basic view + district
# fit our model with .fit() and show results
# we use statsmodels' formula API to invoke the syntax below,
# where we write out the formula using ~
housing_model = ols("price_per_sqm ~ apartment + number_of_whole_rooms + number_of_half_rooms + floor + lift + air_conditioner + furnish_furnished + view_garden + view_panoramic + view_street + district_i + district_ii + district_iii + district_iv + district_v + district_vi + district_vii + district_viii + district_ix + district_x + district_xi + district_xii + district_xiii + district_xiv + district_xv + district_xvi + district_xvii + district_xviii + district_xix + district_xx + district_xxi + district_xxii + district_xxiii", data=data).fit()

# summarize our model
housing_model_summary = housing_model.summary()

# convert our table to HTML and add colors to headers for explanatory purposes
HTML(
(housing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>      <td>price_per_sqm</td>  <th>  R-squared:         </th> <td>   0.273</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th> <td>   0.267</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   45.17</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Tue, 16 Apr 2019</td> <th>  Prob (F-statistic):</th> <td>1.71e-238</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>07:55:26</td>     <th>  Log-Likelihood:    </th> <td> -10667.</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>  3884</td>      <th>  AIC:               </th> <td>2.140e+04</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>  3851</td>      <th>  BIC:               </th> <td>2.161e+04</td>
# </tr>
# <tr>
#   <th>Df Model:</th>              <td>    32</td>      <th>                     </th>     <td> </td>
# </tr>
# <tr>
#   <th>Covariance Type:</th>      <td>nonrobust</td>    <th>                     </th>     <td> </td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#             <td></td>               <th style="background-color:#ffbb78;">coef</th>     <th style="background-color:#c7e9c0;">std err</th>      <th>t</th>      <th style="background-color:#bcbddc;">P>|t|</th>  <th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>
# </tr>
# <tr>
#   <th>Intercept</th>             <td>    7.6594</td> <td>    2.152</td> <td>    3.559</td> <td> 0.000</td> <td>    3.440</td> <td>   11.879</td>
# </tr>
# <tr>
#   <th>apartment</th>             <td>    0.7633</td> <td>    2.212</td> <td>    0.345</td> <td> 0.730</td> <td>   -3.573</td> <td>    5.100</td>
# </tr>
# <tr>
#   <th>number_of_whole_rooms</th> <td>   -0.0129</td> <td>    0.071</td> <td>   -0.181</td> <td> 0.856</td> <td>   -0.152</td> <td>    0.126</td>
# </tr>
# <tr>
#   <th>number_of_half_rooms</th>  <td>   -0.6513</td> <td>    0.118</td> <td>   -5.506</td> <td> 0.000</td> <td>   -0.883</td> <td>   -0.419</td>
# </tr>
# <tr>
#   <th>floor</th>                 <td>   -0.0990</td> <td>    0.037</td> <td>   -2.691</td> <td> 0.007</td> <td>   -0.171</td> <td>   -0.027</td>
# </tr>
# <tr>
#   <th>lift</th>                  <td>    1.1416</td> <td>    0.154</td> <td>    7.433</td> <td> 0.000</td> <td>    0.840</td> <td>    1.443</td>
# </tr>
# <tr>
#   <th>air_conditioner</th>       <td>    2.3603</td> <td>    0.136</td> <td>   17.322</td> <td> 0.000</td> <td>    2.093</td> <td>    2.627</td>
# </tr>
# <tr>
#   <th>furnish_furnished</th>     <td>    1.1659</td> <td>    0.135</td> <td>    8.608</td> <td> 0.000</td> <td>    0.900</td> <td>    1.431</td>
# </tr>
# <tr>
#   <th>view_garden</th>           <td>    0.2122</td> <td>    0.223</td> <td>    0.953</td> <td> 0.340</td> <td>   -0.224</td> <td>    0.648</td>
# </tr>
# <tr>
#   <th>view_panoramic</th>        <td>    1.0495</td> <td>    0.238</td> <td>    4.402</td> <td> 0.000</td> <td>    0.582</td> <td>    1.517</td>
# </tr>
# <tr>
#   <th>view_street</th>           <td>   -0.5403</td> <td>    0.214</td> <td>   -2.529</td> <td> 0.011</td> <td>   -0.959</td> <td>   -0.121</td>
# </tr>
# <tr>
#   <th>district_i</th>            <td>    2.8384</td> <td>    0.327</td> <td>    8.692</td> <td> 0.000</td> <td>    2.198</td> <td>    3.479</td>
# </tr>
# <tr>
#   <th>district_ii</th>           <td>    1.6910</td> <td>    0.257</td> <td>    6.584</td> <td> 0.000</td> <td>    1.187</td> <td>    2.195</td>
# </tr>
# <tr>
#   <th>district_iii</th>          <td>    0.6489</td> <td>    0.349</td> <td>    1.857</td> <td> 0.063</td> <td>   -0.036</td> <td>    1.334</td>
# </tr>
# <tr>
#   <th>district_iv</th>           <td>   -1.0297</td> <td>    0.609</td> <td>   -1.692</td> <td> 0.091</td> <td>   -2.223</td> <td>    0.164</td>
# </tr>
# <tr>
#   <th>district_v</th>            <td>    3.5066</td> <td>    0.250</td> <td>   14.015</td> <td> 0.000</td> <td>    3.016</td> <td>    3.997</td>
# </tr>
# <tr>
#   <th>district_vi</th>           <td>    2.6088</td> <td>    0.245</td> <td>   10.639</td> <td> 0.000</td> <td>    2.128</td> <td>    3.090</td>
# </tr>
# <tr>
#   <th>district_vii</th>          <td>    1.0378</td> <td>    0.284</td> <td>    3.651</td> <td> 0.000</td> <td>    0.480</td> <td>    1.595</td>
# </tr>
# <tr>
#   <th>district_viii</th>         <td>    0.5681</td> <td>    0.285</td> <td>    1.992</td> <td> 0.046</td> <td>    0.009</td> <td>    1.127</td>
# </tr>
# <tr>
#   <th>district_ix</th>           <td>    0.8450</td> <td>    0.287</td> <td>    2.947</td> <td> 0.003</td> <td>    0.283</td> <td>    1.407</td>
# </tr>
# <tr>
#   <th>district_x</th>            <td>   -1.1226</td> <td>    0.538</td> <td>   -2.088</td> <td> 0.037</td> <td>   -2.177</td> <td>   -0.069</td>
# </tr>
# <tr>
#   <th>district_xi</th>           <td>    0.6602</td> <td>    0.279</td> <td>    2.368</td> <td> 0.018</td> <td>    0.114</td> <td>    1.207</td>
# </tr>
# <tr>
#   <th>district_xii</th>          <td>    0.8861</td> <td>    0.317</td> <td>    2.794</td> <td> 0.005</td> <td>    0.264</td> <td>    1.508</td>
# </tr>
# <tr>
#   <th>district_xiii</th>         <td>    0.6879</td> <td>    0.257</td> <td>    2.680</td> <td> 0.007</td> <td>    0.185</td> <td>    1.191</td>
# </tr>
# <tr>
#   <th>district_xiv</th>          <td>   -0.2983</td> <td>    0.315</td> <td>   -0.947</td> <td> 0.344</td> <td>   -0.916</td> <td>    0.319</td>
# </tr>
# <tr>
#   <th>district_xv</th>           <td>    0.0736</td> <td>    0.607</td> <td>    0.121</td> <td> 0.903</td> <td>   -1.116</td> <td>    1.263</td>
# </tr>
# <tr>
#   <th>district_xvi</th>          <td>   -0.5274</td> <td>    0.926</td> <td>   -0.570</td> <td> 0.569</td> <td>   -2.343</td> <td>    1.288</td>
# </tr>
# <tr>
#   <th>district_xvii</th>         <td>   -0.1558</td> <td>    1.166</td> <td>   -0.134</td> <td> 0.894</td> <td>   -2.441</td> <td>    2.130</td>
# </tr>
# <tr>
#   <th>district_xviii</th>        <td>   -1.2444</td> <td>    0.708</td> <td>   -1.757</td> <td> 0.079</td> <td>   -2.633</td> <td>    0.144</td>
# </tr>
# <tr>
#   <th>district_xix</th>          <td>    0.3720</td> <td>    0.898</td> <td>    0.414</td> <td> 0.679</td> <td>   -1.389</td> <td>    2.133</td>
# </tr>
# <tr>
#   <th>district_xx</th>           <td>   -1.1135</td> <td>    1.062</td> <td>   -1.048</td> <td> 0.295</td> <td>   -3.196</td> <td>    0.969</td>
# </tr>
# <tr>
#   <th>district_xxi</th>          <td>   -0.0272</td> <td>    0.925</td> <td>   -0.029</td> <td> 0.977</td> <td>   -1.841</td> <td>    1.786</td>
# </tr>
# <tr>
#   <th>district_xxii</th>         <td>   -1.8423</td> <td>    0.926</td> <td>   -1.990</td> <td> 0.047</td> <td>   -3.657</td> <td>   -0.027</td>
# </tr>
# <tr>
#   <th>district_xxiii</th>        <td>   -1.4038</td> <td>    1.825</td> <td>   -0.769</td> <td> 0.442</td> <td>   -4.982</td> <td>    2.174</td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#   <th>Omnibus:</th>       <td>1289.638</td> <th>  Durbin-Watson:     </th> <td>   1.896</td>
# </tr>
# <tr>
#   <th>Prob(Omnibus):</th>  <td> 0.000</td>  <th>  Jarque-Bera (JB):  </th> <td>7151.887</td>
# </tr>
# <tr>
#   <th>Skew:</th>           <td> 1.477</td>  <th>  Prob(JB):          </th> <td>    0.00</td>
# </tr>
# <tr>
#   <th>Kurtosis:</th>       <td> 8.956</td>  <th>  Cond. No.          </th> <td>4.70e+15</td>
# </tr>
# </table><br/><br/>Warnings:<br/>[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.<br/>[2] The smallest eigenvalue is 3.09e-27. This might indicate that there are<br/>strong multicollinearity problems or that the design matrix is singular.

# %%
print(housing_model.summary())

# %%
# basic specifications + basic decoration + basic view + district + heating 
# fit our model with .fit() and show results
# we use statsmodels' formula API to invoke the syntax below,
# where we write out the formula using ~
housing_model = ols("price_per_sqm ~ apartment + number_of_whole_rooms + number_of_half_rooms + floor + lift + air_conditioner + furnish_furnished + view_garden + view_panoramic + view_street + district_i + district_ii + district_iii + district_iv + district_v + district_vi + district_vii + district_viii + district_ix + district_x + district_xi + district_xii + district_xiii + district_xiv + district_xv + district_xvi + district_xvii + district_xviii + district_xix + district_xx + district_xxi + district_xxii + district_xxiii + heating_gas + heating_wall_heating + heating_combination + heating_ceiling + heating_central_heating + heating_electric + heating_floor + heating_circulating + heating_district", data=data).fit()

# summarize our model
housing_model_summary = housing_model.summary()

# convert our table to HTML and add colors to headers for explanatory purposes
HTML(
(housing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>      <td>price_per_sqm</td>  <th>  R-squared:         </th> <td>   0.290</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th> <td>   0.282</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th> <td>   38.21</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Tue, 16 Apr 2019</td> <th>  Prob (F-statistic):</th> <td>3.46e-250</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>08:17:56</td>     <th>  Log-Likelihood:    </th> <td> -10621.</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td>  3884</td>      <th>  AIC:               </th> <td>2.133e+04</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td>  3842</td>      <th>  BIC:               </th> <td>2.159e+04</td>
# </tr>
# <tr>
#   <th>Df Model:</th>              <td>    41</td>      <th>                     </th>     <td> </td>
# </tr>
# <tr>
#   <th>Covariance Type:</th>      <td>nonrobust</td>    <th>                     </th>     <td> </td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#              <td></td>                <th style="background-color:#ffbb78;">coef</th>     <th style="background-color:#c7e9c0;">std err</th>      <th>t</th>      <th style="background-color:#bcbddc;">P>|t|</th>  <th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>
# </tr>
# <tr>
#   <th>Intercept</th>               <td>    7.5204</td> <td>    2.133</td> <td>    3.526</td> <td> 0.000</td> <td>    3.338</td> <td>   11.702</td>
# </tr>
# <tr>
#   <th>apartment</th>               <td>    1.6317</td> <td>    2.194</td> <td>    0.744</td> <td> 0.457</td> <td>   -2.670</td> <td>    5.934</td>
# </tr>
# <tr>
#   <th>number_of_whole_rooms</th>   <td>    0.0088</td> <td>    0.073</td> <td>    0.120</td> <td> 0.904</td> <td>   -0.134</td> <td>    0.152</td>
# </tr>
# <tr>
#   <th>number_of_half_rooms</th>    <td>   -0.5998</td> <td>    0.118</td> <td>   -5.093</td> <td> 0.000</td> <td>   -0.831</td> <td>   -0.369</td>
# </tr>
# <tr>
#   <th>floor</th>                   <td>   -0.0841</td> <td>    0.037</td> <td>   -2.253</td> <td> 0.024</td> <td>   -0.157</td> <td>   -0.011</td>
# </tr>
# <tr>
#   <th>lift</th>                    <td>    1.0693</td> <td>    0.161</td> <td>    6.627</td> <td> 0.000</td> <td>    0.753</td> <td>    1.386</td>
# </tr>
# <tr>
#   <th>air_conditioner</th>         <td>    2.3191</td> <td>    0.138</td> <td>   16.769</td> <td> 0.000</td> <td>    2.048</td> <td>    2.590</td>
# </tr>
# <tr>
#   <th>furnish_furnished</th>       <td>    1.1662</td> <td>    0.134</td> <td>    8.690</td> <td> 0.000</td> <td>    0.903</td> <td>    1.429</td>
# </tr>
# <tr>
#   <th>view_garden</th>             <td>    0.4136</td> <td>    0.223</td> <td>    1.857</td> <td> 0.063</td> <td>   -0.023</td> <td>    0.850</td>
# </tr>
# <tr>
#   <th>view_panoramic</th>          <td>    1.1484</td> <td>    0.238</td> <td>    4.834</td> <td> 0.000</td> <td>    0.683</td> <td>    1.614</td>
# </tr>
# <tr>
#   <th>view_street</th>             <td>   -0.3475</td> <td>    0.214</td> <td>   -1.625</td> <td> 0.104</td> <td>   -0.767</td> <td>    0.072</td>
# </tr>
# <tr>
#   <th>district_i</th>              <td>    2.6961</td> <td>    0.326</td> <td>    8.265</td> <td> 0.000</td> <td>    2.057</td> <td>    3.336</td>
# </tr>
# <tr>
#   <th>district_ii</th>             <td>    1.6075</td> <td>    0.257</td> <td>    6.248</td> <td> 0.000</td> <td>    1.103</td> <td>    2.112</td>
# </tr>
# <tr>
#   <th>district_iii</th>            <td>    0.6956</td> <td>    0.346</td> <td>    2.008</td> <td> 0.045</td> <td>    0.016</td> <td>    1.375</td>
# </tr>
# <tr>
#   <th>district_iv</th>             <td>   -0.6227</td> <td>    0.609</td> <td>   -1.023</td> <td> 0.306</td> <td>   -1.816</td> <td>    0.571</td>
# </tr>
# <tr>
#   <th>district_v</th>              <td>    3.3325</td> <td>    0.252</td> <td>   13.216</td> <td> 0.000</td> <td>    2.838</td> <td>    3.827</td>
# </tr>
# <tr>
#   <th>district_vi</th>             <td>    2.4097</td> <td>    0.248</td> <td>    9.722</td> <td> 0.000</td> <td>    1.924</td> <td>    2.896</td>
# </tr>
# <tr>
#   <th>district_vii</th>            <td>    0.8697</td> <td>    0.286</td> <td>    3.045</td> <td> 0.002</td> <td>    0.310</td> <td>    1.430</td>
# </tr>
# <tr>
#   <th>district_viii</th>           <td>    0.4382</td> <td>    0.286</td> <td>    1.531</td> <td> 0.126</td> <td>   -0.123</td> <td>    0.999</td>
# </tr>
# <tr>
#   <th>district_ix</th>             <td>    0.6978</td> <td>    0.286</td> <td>    2.438</td> <td> 0.015</td> <td>    0.137</td> <td>    1.259</td>
# </tr>
# <tr>
#   <th>district_x</th>              <td>   -0.8594</td> <td>    0.536</td> <td>   -1.605</td> <td> 0.109</td> <td>   -1.909</td> <td>    0.191</td>
# </tr>
# <tr>
#   <th>district_xi</th>             <td>    0.7358</td> <td>    0.277</td> <td>    2.660</td> <td> 0.008</td> <td>    0.194</td> <td>    1.278</td>
# </tr>
# <tr>
#   <th>district_xii</th>            <td>    0.7677</td> <td>    0.316</td> <td>    2.433</td> <td> 0.015</td> <td>    0.149</td> <td>    1.386</td>
# </tr>
# <tr>
#   <th>district_xiii</th>           <td>    0.6780</td> <td>    0.255</td> <td>    2.657</td> <td> 0.008</td> <td>    0.178</td> <td>    1.178</td>
# </tr>
# <tr>
#   <th>district_xiv</th>            <td>   -0.3437</td> <td>    0.312</td> <td>   -1.101</td> <td> 0.271</td> <td>   -0.956</td> <td>    0.268</td>
# </tr>
# <tr>
#   <th>district_xv</th>             <td>    0.2997</td> <td>    0.603</td> <td>    0.497</td> <td> 0.619</td> <td>   -0.883</td> <td>    1.483</td>
# </tr>
# <tr>
#   <th>district_xvi</th>            <td>   -0.5614</td> <td>    0.917</td> <td>   -0.612</td> <td> 0.541</td> <td>   -2.360</td> <td>    1.237</td>
# </tr>
# <tr>
#   <th>district_xvii</th>           <td>    0.2798</td> <td>    1.160</td> <td>    0.241</td> <td> 0.809</td> <td>   -1.994</td> <td>    2.553</td>
# </tr>
# <tr>
#   <th>district_xviii</th>          <td>   -1.1046</td> <td>    0.702</td> <td>   -1.573</td> <td> 0.116</td> <td>   -2.481</td> <td>    0.272</td>
# </tr>
# <tr>
#   <th>district_xix</th>            <td>    0.5264</td> <td>    0.890</td> <td>    0.591</td> <td> 0.554</td> <td>   -1.219</td> <td>    2.272</td>
# </tr>
# <tr>
#   <th>district_xx</th>             <td>   -1.1520</td> <td>    1.052</td> <td>   -1.095</td> <td> 0.274</td> <td>   -3.215</td> <td>    0.911</td>
# </tr>
# <tr>
#   <th>district_xxi</th>            <td>    0.1549</td> <td>    0.918</td> <td>    0.169</td> <td> 0.866</td> <td>   -1.645</td> <td>    1.955</td>
# </tr>
# <tr>
#   <th>district_xxii</th>           <td>   -2.0945</td> <td>    0.920</td> <td>   -2.277</td> <td> 0.023</td> <td>   -3.898</td> <td>   -0.291</td>
# </tr>
# <tr>
#   <th>district_xxiii</th>          <td>   -1.9306</td> <td>    1.831</td> <td>   -1.054</td> <td> 0.292</td> <td>   -5.520</td> <td>    1.659</td>
# </tr>
# <tr>
#   <th>heating_gas</th>             <td>   -0.9720</td> <td>    0.249</td> <td>   -3.898</td> <td> 0.000</td> <td>   -1.461</td> <td>   -0.483</td>
# </tr>
# <tr>
#   <th>heating_wall_heating</th>    <td>    1.6450</td> <td>    1.097</td> <td>    1.500</td> <td> 0.134</td> <td>   -0.505</td> <td>    3.795</td>
# </tr>
# <tr>
#   <th>heating_combination</th>     <td>   -1.1453</td> <td>    0.188</td> <td>   -6.089</td> <td> 0.000</td> <td>   -1.514</td> <td>   -0.777</td>
# </tr>
# <tr>
#   <th>heating_ceiling</th>         <td>    0.1284</td> <td>    1.215</td> <td>    0.106</td> <td> 0.916</td> <td>   -2.254</td> <td>    2.511</td>
# </tr>
# <tr>
#   <th>heating_central_heating</th> <td>   -0.8871</td> <td>    0.194</td> <td>   -4.572</td> <td> 0.000</td> <td>   -1.268</td> <td>   -0.507</td>
# </tr>
# <tr>
#   <th>heating_electric</th>        <td>    0.4973</td> <td>    0.397</td> <td>    1.252</td> <td> 0.211</td> <td>   -0.281</td> <td>    1.276</td>
# </tr>
# <tr>
#   <th>heating_floor</th>           <td>    3.8884</td> <td>    1.203</td> <td>    3.232</td> <td> 0.001</td> <td>    1.529</td> <td>    6.247</td>
# </tr>
# <tr>
#   <th>he

# %%
print(housing_model.summary())

# %%
plt.figure(figsize = (20,20))
plt.scatter(data['number_of_half_rooms'], data['size(sqm)'], color = 'green')
plt.xlabel('number of half rooms', fontsize = 14)
plt.ylabel('size(sqm)', fontsize = 14)
plt.grid(True)
plt.savefig('half_room_1.png')
plt.show()

# %%
plt.figure(figsize = (20,20))
plt.scatter(data['number_of_half_rooms'], data['floor'], color = 'green')
plt.xlabel('number of half rooms', fontsize = 14)
plt.ylabel('floor', fontsize = 14)
plt.grid(True)
plt.savefig('half_room_3.png')
plt.show()

# %%
plt.subplots(figsize=(20,20))
sns.boxplot(x = 'view_total', y = 'number_of_half_rooms', data = data)
plt.savefig('half_room_2.png')

# %%
plt.subplots(figsize=(20,20))
sns.boxplot(x = 'furnish_total', y = 'number_of_half_rooms', data = data)
plt.savefig('half_room_4.png')

# %%
plt.figure(figsize = (20,20))
plt.scatter(data['number_of_half_rooms'], data['utilities_fee_per_sqm'], color = 'green')
plt.xlabel('number of half rooms', fontsize = 14)
plt.ylabel('utilities fee per sqm', fontsize = 14)
plt.grid(True)
plt.savefig('half_room_5.png')
plt.show()

# %%
sns.scatterplot(x = "longitude", y="latitude", hue="number_of_half_rooms", data=data)
plt.savefig('half_room_6.png')

# %%
plt.figure(figsize = (20,20))
plt.scatter(data['floor'], data['price_per_sqm'], color = 'green')
plt.xlabel('floor', fontsize = 14)
plt.ylabel('price per sqm', fontsize = 14)
plt.grid(True)
plt.savefig('floor_1.png')
plt.show()

# %%
sns.catplot(x = "floor", y="price_per_sqm", hue="lift", kind="swarm", data=data)
plt.savefig('floor_2.png')

# %%
plt.figure(figsize = (20,20))
plt.scatter(data['floor'], data['size(sqm)'], color = 'green')
plt.xlabel('floor', fontsize = 14)
plt.ylabel('size(sqm)', fontsize = 14)
plt.grid(True)
plt.savefig('floor_3.png')
plt.show()

# %%
plt.figure(figsize = (20,20))
plt.scatter(data['floor'], data['number_of_half_rooms'], color = 'green')
plt.xlabel('floor', fontsize = 14)
plt.ylabel('number of half rooms', fontsize = 14)
plt.grid(True)
plt.savefig('floor_5.png')
plt.show()

# %%
sns.catplot(y="heating_total", hue="condition_of_property", kind="count", palette="pastel", data=data, height=10, aspect=2);
plt.savefig('heating_1.png')

# %%
plt.subplots(figsize=(20,20))
sns.boxplot(x="heating_total", y="utilities_fee_per_sqm", data=data, palette="Set3")
plt.savefig('heating_2.png')
